# %%
import ROOT
# %jsroot on
# Out:
# Welcome to JupyROOT 6.16/00

# %%
ROOT.TGeoManager.Import('./data/geometryJLEIC.root')
# Out:
# <ROOT.TGeoManager object ("VGM Root geometry") at 0x62bd490>
# Info in <TGeoManager::Import>: Reading geometry from file: ./data/geometryJLEIC.root
# Info in <TGeoManager::CloseGeometry>: Geometry loaded from file...
# Info in <TGeoManager::SetTopVolume>: Top volume is World. Master volume is World
# Info in <TGeoNavigator::BuildCache>: --- Maximum geometry depth set to 100
# Info in <TGeoManager::CloseGeometry>: Voxelization retrieved from file
# Info in <TGeoManager::CountLevels>: max level = 3, max placements = 3884
# Info in <TGeoManager::CloseGeometry>: 6873 nodes/ 156 volume UID's in VGM Root geometry
# Info in <TGeoManager::CloseGeometry>: ----------------modeler ready----------------

# %%
canvas = ROOT.TCanvas('canvas', 'canvas',800,600)
volume = ROOT.gGeoManager.GetTopVolume()
volume.SetTransparency(60)
volume.Draw()
# Out:
# <div id="root_plot_1"
#      style="width: 600px; height: 600px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...
